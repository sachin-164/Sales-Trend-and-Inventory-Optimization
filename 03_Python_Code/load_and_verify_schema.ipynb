# %%
import pandas as pd

# %%
sales_file = "../01_Original_Files/honeyrich_export_sales.csv"
warehouse_file = "../01_Original_Files/honeyrich_supply_logs.csv"

# %%
sales = pd.read_csv(sales_file)
warehouse = pd.read_csv(warehouse_file)

# %%
print("\nSales Columns:")
print(sales.columns)
# Out:
# Sales Columns:
# Index(['Order_ID', 'Batch_ID', 'Destination', 'Quantity_Sold_KG',
#        'Selling_Price_Per_KG', 'Sale_Date', 'Revenue'],
#       dtype='str')

# %%
print("\nWarehouse Columns:")
print(warehouse.columns)
# Out:
# Warehouse Columns:
# Index(['Batch_ID', 'Vendor_Name', 'Product_Name', 'Quantity', 'Unit',
#        'Cost_Per_KG', 'Defect_Rate_Pct', 'Procurement_Date'],
#       dtype='str')

# %%
print("\nTotal Sales Records:", len(sales))
print("Total Warehouse Records:", len(warehouse))
# Out:
# Total Sales Records: 14500
# Total Warehouse Records: 10257
